# %%
## 変数や関数の定義

from pathlib import Path
import json
from watson_developer_cloud import PersonalityInsightsV3
from decimal import Decimal, ROUND_HALF_UP, ROUND_HALF_EVEN
from collections import OrderedDict
import pprint
import itertools
import get_my_tweets_over200 as tw

# 本の文章データ名
books = ["bocchan.txt", "chumonno_oi_ryoriten.txt", "hashire_merosu.txt", "kaijin_nijumenso.txt", "ningen_shikkaku.txt"]
# 抽出した本のストーリーを保存するフォルダ
stored_path = Path("./extracted_bookdata")
# 全ての本の分析結果を保存するJSONファイルの名前
analyzed_all_book_json_name = "analyzed_all_book.json"

def get_personality(text):
    """
    Personality Insightsを用いた性格分析の結果を取得する
    参考サイト：http://tmngtm.hatenablog.com/entry/2016/10/14/203901
    -> return responseで400コードが出てうまくいかず(後で分かったことだが、恐らくContent-Languageをenにしていた...)
    -> 公式マニュアルを読み解いた
    ※事前に、pip install --upgrade watson-developer-cloud
    """
    api_version = ""
    api_username = ""
    api_password = ""
    api_url = "https://gateway.watsonplatform.net/personality-insights/api"
    
    personality_insights = PersonalityInsightsV3(
        version = api_version,
        username = api_username,
        password = api_password,
        url = api_url
    )
    
    profile = personality_insights.profile(
        content = text,
        content_type = "text/plain",
        accept = "application/json",
        content_language = "ja",
        accept_language = "en",
        raw_scores = True,
    )
    
    return profile

def get_personality_old(text):
    """
    上記参考サイトのコード＋少々改変版。
    Content-Languageをjaにしていればできてたっぽい。
    """
    # endpoint url
    api_url = "https://gateway.watsonplatform.net/personality-insights/api/v2/profile"
    # username and password for this api
    api_username = ""
    api_password = ""
    
    # set query
    query = {
        "include_raw": "false",
        "header": "false"
    }
    
    # set header
    headers = {
        "Content-Type": "text/plain", # 入力テキストの形式。今回はstringのテキストを渡す設定。
        "Content-Language": "en",     # 入力言語モードの指定。jaとすると日本語の入力を受け付ける。
        "Accept": "application/json", # 応答ファイルの形式。今回はjson形式で受け取る。
        "Accept-Language": "en",      # 処理言語モードの設定。jaとすると日本語として処理する。
        "include_raw": "false"
    }
    
    # set body
    body = text
    body = body.encode("utf-8") # 参考サイトのコードに追記
    
    # post
    response = requests.post(
        api_url,
        auth = HTTPBasicAuth(api_username, api_password),
        params = query,
        headers = headers,
        data = body
    )
    return response

def convert_dict_to_json(orig_dict, indent = 4):
    """
    辞書からJSON形式に変換する
    参考サイト：https://tmg0525.hatenadiary.jp/entry/2018/03/30/204448
    """
    return json.dumps(orig_dict, indent = indent)

def load_json_as_dict(json_name):
    """
    JSON形式の文字列を辞書として読み込む
    参考サイト：https://note.nkmk.me/python-json-load-dump/
    """
    with open("./" + json_name, "r") as json_file:
        return json.load(json_file, object_pairs_hook = OrderedDict)

def sort_personality(a_book_result):
    """
    a_book_resultを性格の値で降順にソートし、リストとしてreturnする
    returnされたリストをスライスすれば一部を取得できる
    本のカテゴリ分けの時に使う
    """
    return sorted(a_book_result.items(), key = lambda x: x[1], reverse = True)

# %%
## 本(今回は全5冊)の文章データをPersonality Insightsに入力して分析させる
## その結果を、JSONファイルに変換して保存する
## -> このセルを1回実行しておけば、ファイルを読み込むだけで本の分析結果を利用できる

# 全ての本(今回は5冊)の分析結果を格納する
# { { book1: { personality_name1: percentile1, personality2: percentile2, ... } }, ... , { book5: { personality5: percentile5, ... } } }
# 後でJSONファイルとして保存するため、順序付き辞書を使う
# 参考サイト：https://note.nkmk.me/python-collections-ordereddict/
all_book_big5 = OrderedDict()

for book in books:
    book_path = Path(stored_path.name + "/" + book) # Path(Path("./extracted_bookdata") / book) でもOK
    # 入力となる本の文章データ
    story = book_path.read_text(encoding="utf-8")
    # personality insightsに、本の文章データを1つずつ順番に分析させる
    story_personality_dict = get_personality(story)
    
    # 本の性格
    personality_name = [big5["name"] for big5 in story_personality_dict["personality"]]
    # 性格の値。小数点第2位で四捨五入した後、decimal.Decimalからfloatに変換している。
    # 参考サイト(四捨五入)：https://note.nkmk.me/python-round-decimal-quantize/
    personality_percentile = [float(Decimal(str(big5["percentile"])).quantize(Decimal('0.01'), rounding=ROUND_HALF_UP)) \
                              for big5 in story_personality_dict["personality"]]
    # 1冊の本の分析結果
    a_book_big5 = OrderedDict(zip(personality_name, personality_percentile))
    # 全体の分析結果の辞書に追加
    all_book_big5[book] = a_book_big5
    
    print("finished analyzing {} .".format(book))
    # JSONとして出力したくなったらコメントアウト解除
    # print(convert_dict_to_json(story_personality_dict, 4))

print("finished analyzing all({}) books.".format(len(books)))

# 全ての本の分析結果をJSONファイルとして保存する
# このノートブックをシャットダウンしたら、jsonファイルの内容を閲覧できるようになる(それまでは何故か内容が更新されていない)
fw = open(analyzed_all_book_json_name, "w")
json.dump(all_book_big5, fw, indent = 4)
print("registered result of analysis with file: {}".format(analyzed_all_book_json_name))
# Out:
# finished analyzing bocchan.txt .
# finished analyzing chumonno_oi_ryoriten.txt .
# finished analyzing hashire_merosu.txt .
# finished analyzing kaijin_nijumenso.txt .
# finished analyzing ningen_shikkaku.txt .
# finished analyzing all(5) books.
# registered result of analysis with file: analyzed_all_book.json

# %%
## 分析結果を基に、本のカテゴリ分けを行う。

# カテゴリの通し番号
serial_numbers = [i + 1 for i in range(10)]

# Agreeableness: 協調性, Conscientiousness: 真面目さ, Emotional range: 精神的安定性, Extraversion: 外向性, Openness: 開放性
# 参考サイト：https://note.nkmk.me/python-math-factorial-permutations-combinations/
big5_list = ["Agreeableness", "Conscientiousness", "Emotional range", "Extraversion", "Openness"]

# big5から2つの性格を選ぶ組み合わせを列挙する
# JSONファイルの内容に合わせて要素をsetに変換する(順番を考慮すると)
category_patterns = [set(pat) for pat in itertools.combinations(big5_list, 2)]

# 本ごとのカテゴリ分けを記録する辞書
all_book_category_table = OrderedDict()

for book in books:
    # 本の分析結果のJSONファイルをそれぞれ読み込み、値の大きい順にソートする
    loaded_all_book_big5 = load_json_as_dict(analyzed_all_book_json_name)[book]
    sorted_result = sort_personality(loaded_all_book_big5)
    
    # big5のうち大きい順から2番目までの値の性格名のみを取得し、その本のカテゴリとする(例：{Openness, Extraversion})
    # この時、複数の性格の順番を考慮させないために、setで用意する
    # 2つを組み合わせているため、1つだけの場合よりも幅広くカテゴリ分けできそう
    book_category = {big5_elm[0] for big5_elm in sorted_result[0:2]}
    all_book_category_table[book] = book_category

pprint.pprint(category_patterns)
pprint.pprint(all_book_category_table)
print(all_book_category_table["bocchan.txt"] in category_patterns)
# Out:
# [{'Agreeableness', 'Conscientiousness'},
#  {'Agreeableness', 'Emotional range'},
#  {'Extraversion', 'Agreeableness'},
#  {'Agreeableness', 'Openness'},
#  {'Conscientiousness', 'Emotional range'},
#  {'Extraversion', 'Conscientiousness'},
#  {'Openness', 'Conscientiousness'},
#  {'Extraversion', 'Emotional range'},
#  {'Openness', 'Emotional range'},
#  {'Extraversion', 'Openness'}]
# OrderedDict([('bocchan.txt', {'Openness', 'Emotional range'}),
#              ('chumonno_oi_ryoriten.txt', {'Extraversion', 'Openness'}),
#              ('hashire_merosu.txt', {'Extraversion', 'Openness'}),
#              ('kaijin_nijumenso.txt', {'Agreeableness', 'Openness'}),
#              ('ningen_shikkaku.txt', {'Agreeableness', 'Openness'})])
# True

# %%
## 自分のツイートをAPIに入力して結果を見る
## 一番上のセルでget_my_tweets_over200をimport済み

# ツイートの取得
tw.userTweets = [] # import元にある、取得したツイートの格納リストの中身をリセットする(これで繰り返し実行してもOK)
tw.use_function()

print(tw.userTweets)
print()
print(len(tw.userTweets))
print()

userTweets_joined = " ".join(tw.userTweets)
print(userTweets_joined)

# 自分のツイートをPersonality Insightsに入れて結果を見る
result = get_personality(userTweets_joined)
print(convert_dict_to_json(result, 4))
# Out:
# 自分のuser_idを入力してください
# >> sftn_sk
# ----------------------------------------------------
# aa
# 1022000600752513025
# bb
# ツイートの取得が終了しました
#
# ['今日めっちゃ近くの場所にあゆタロウさんいたんか…(°_°)', 'LINE通話中にいきなりPCの電源切れてびびった', '実際の譜面見てみたけど、これで星9でええやろ\n\nhttps://t.co/04mP99Rm0I', 'RT @amanao_: @XDAY1206 実行してみました！ https://t.co/Px9C8xl8JF', 'RT @XDAY1206: void setup 公式歌詞\n公式....歌....詞....？ https://t.co/AJrQW1b1n3', 'キムドンフン引退ってマジ！？\n衝撃…', '名前いかつい笑\nグ  ラ  ン  デ  ュ  ー  ク https://t.co/gXFLTxOXog', '布団でノートPC使ってたら寝落ちしてた', 'おージョコビッチ優勝か', 'エルモがエルモにリプ送ってて草 https://t.co/PKThdMp9KJ', '黒川、徹底して幹事拒否してるの笑う', 'あっっっつ', '全米オープン、大坂なおみが優勝で錦織ベスト4とか凄すぎ', 'すげえ、TrelloってiOSアプリ版もあるのか', 'GitLFS導入できぬ', '錦織劣勢の裏で大谷19号HR打ってるw', 'バイト面接終わりー', 'グアム旅行で朝早かったおかげで、目覚め良くなった気がする', 'グアムロス', '逆転裁判のアニメ続編やるのか！', '家着いたんで片付けします😭', '初海外、楽しかったし新鮮だった🌴', '@riiiiku08 マンゴーはクセが強いかも。\n\nそれは辛い…\nバラ売りしてないところもあるのか(-_-;)', '@riiiiku08 個人的には飲みやすかったけど、林檎の方が断然良かった！\n\n6缶もあると消
#
# この歌好きだった https://t.co/mdc1M52qAx RT @14023104: 面接官「今日はどうやってここまで来ましたか？」
#
# 就活生「陸路です！就活だけに陸ルートwwガハハww」
#
# 担当医「面接を終了します」 オーキド博士マジか… @kosuke_kando 結局「ケツだけ」だからケツなんじゃね？笑 劇場版名探偵コナン 沈黙の万引き犯 https://t.co/RXVD60VzRK 帰宅じゃー 光の旅とか超のBGMとかも流れてる…
# 選曲範囲広すぎ笑 10万円でくじの元を取るやつ、ドラゴンボールやんけ
# 無印BGMとかFとか流れてて良い 今度はG… ※帰省先にて 家のすぐそばの祭りの抽選会、今年も参加してるけど、結果発表の効率悪すぎる笑
# ITの力で何とかしようぜ(適当) RT @sudokeeeeen: 映画泥棒のCMを再現してみた
# #C94 #C94コスプレ #映画泥棒 https://t.co/WHelcIvCm1 SVMは普通に出るんかい https://t.co/RQTHbkwS6o Support Vector Regressionのつもりが、全然違う結果でビビった(しかもトップにてんが) https://t.co/pHbxDRas0G 家にムカデ出たwwwww RT @SFphoto87: ▼神奈川少年男子国体メンバー▼
#    ・工藤眞明也選手
#    ・澤田浩輔選手
#    ・細野奨太選手
#    ・戸塚寛太選手
#    ・和泉希選手
#    ・星陸也選手
# （以上、横浜創英高校）
#    ・井上拓海選手
# （東海大相模高校） https://t.… 今日から栃木帰省だけど高速くそ混んでる(しかも事故渋滞) RT @kazuneet: jupyter notebook使いの皆様へ。東大松尾研の人に教えてもらいました。
# コーディングする前にこのおまじないをしてみてください。
# 感動します。
# from IPython.core.display import display, HTML… ソフトボールめっちゃ良い試合だった…！ いつの間にかランニング17日目だった
# 案外続いてるなぁ ランニング中に受動喫煙とか拷問でしかない @pochina_512 うちだったら、先生不在でやってそう... @pochina_512 東北人だったのかｗ 87123ハット被りverを見た 院生が書いた中間発表抄録、本文の文字サイズが9じゃなくて10になってる・・・ トレンドに野獣の日入ってて草 チマチマやってたPythonの演習問題101問をついに終えた 内定者バイトまた落ちた えび中マジかすげえ https://t.co/sBoJl6vOFL @kurosho59 物理的にボコされてて草 @kurosho59 もしそうなったら、黄先生にボコボコにされる未来しか見えない @kurosho59 もっと先まで来なかったら流石に笑えねえよ… データセット来たあああああああああ
# (もはや最近気にしてなかった) 天気悪くても暑いな RT @SmashBrosJP: 【お知らせ】8月8日（水）の23時より、「大乱闘スマッシュブラザーズ SPECIAL Direct 2018.8.8」を放送します。ディレクターの桜井さんがソフトの新情報をお届けします。https://t.co/sSLitnQFbB
# #スマブラ… RT @ayutaroukun: 全日本実業団に行ってきました！【ソフトテニス】
# https://t.co/Zc9TgrAQTF https://t.co/o7UIdCjbHI 今日のランニング
# 予定: 8km
# 現実: 13km
# 男子個人結果
# 1位 井上・米澤(東海大相模)
# 2位 松尾・金子(横浜創英)
# 3位 大日向・大崎(東海大相模)
# 3位 海野・青木(秦野)
# 5位 澤田・和泉(横浜創英)
# 5位 増田・小林(東海大相模)
# 5位 安田・… RT @GOMU218: 東日本選手権大会、一般男子途中経過ベスト８が出揃いました。
# 安藤・内田(早稲田)
# 小田島・工藤(慶応大・宮城mori.moriクラブ)
# 林田・柴田(ヨネックス)
# 中本・鈴木(福井県庁)
# 本倉・丸山(明治大)
# 稲積・森田(富山氷見市ST協会・宮城mori… 下手したら、試合してるところ観たことあるかもしれんな もしやとは思っていたけど、やっぱりあの人だったのか・・・！ ！？！？！？ https://t.co/0Pp1INWf4Z ほろよい冷やしパインうめーな！ RT @gbc_hosei: 【重要なお知らせ】
# GBCは20日4限が今学期最後の開室時限となります。5限は閉室致しますので、レポートの回収はお早めに！
# また、4年生SAも同日にGBC卒業となりますので、4年生に聞きたい事がある場合は今学期中に是非どうぞ( *´︶`*) 左のやつ、兄者が昔やってたやつだ https://t.co/LGfPQOwI0L 通信制限キタタタタ(入院中にスマホ使いまくった) 海老名戻ってきたら土砂降りで草 パスポートキタタタタ ナダルつっっっっよ 帰ってきたら、錦織が1セット取り返して1-1になってた 急遽家族で飲みに行くことになって草 論文の内容理解できてなくて読むスピード落ちまくってる ブロリーも好きだけど、パラガスのキャラが濃すぎるんだよな… トレンド1位がブロリーは草 RT @radis318: これな、ブロリーじゃなくてヤムチャにみえん？？wwwwwきのせい？wwwww
# #ドラゴンボール映画 https://t.co/CuxQJ3gno3 RT @oricon: 映画『ドラゴンボール』正式タイトル決定　今作の敵は伝説のサイヤ人・ブロリー（写真 全2枚）
# https://t.co/9EkfEexvNz
#
#  #鳥山明 #アニメ #映画 #ドラゴンボール #DragonBall @DB_super2015 RT @tomoyanandayo: 怖いと話題の尾田先生の悟空なんですが 台詞入れると よりセェコパス感出てしまった... https://t.co/ywO7Q8pXdi TOEICの点数上がってた 外界暑すぎ 退        院 RT @sentoki: CUDAとCuPyのインストールが済んだ。落とし穴に何度も落ちて、時間がかかってしまった。Qiitaの記事を真似して、numpyとの速度比較をしてみた。ノーパソのGeForce940MXでも約6000倍の速さでした。 https://t.co/BiPS… RT @AI_m_lab: ご参考までに
# ▼Pythonの機械学習ライブラリ「scikit-learn」で実践する「教師あり学習」「教師なし学習…
# https://t.co/RT1nzZ2huk
# #machinelearning RT @A_I_News: Pythonの機械学習ライブラリ「scikit-learn」で実践する「教師あり学習」「教師なし学習」 (1/3) https://t.co/aebhyWwS0T RT @kandai_tennis: 【西日本インカレ】
# 男子
# 決勝
#
# 対四日市大学
# 谷口飯田3ー④柳田宮里
# 阪本奥村④ー2大頭篠原
# 石田大橋④ー3徳丸平川
#
# ②ー1勝ちました‼️
#
# 以上の結果より、優勝です！ 左手だけでできることが増えてる… 病院いるときの地震こえーな… @sting4869 @kuwaji_960 あーそういうことね笑
# 把握した @kuwaji_960 構わんけど、俺に聞くのか笑 暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇暇�
# 明日（6/20）正午は、春期の応用・高度の合格発表です💮
# https://t.co/0qVJn2V3w5
#
# #応用情報技術者
# #プロジェクトマネージャ
# #データベーススペシャリスト
# #エンベデッドシステムスペシャリスト… ネ申 https://t.co/gAVetiGsx5 やっとオープンラボ終わった〜 今日の懇親会で新しい食堂の唐揚げ旨いって分かったので今度唐揚げメニュー頼んでみるか〜 この時間にそこそこしっかり飯を食うデブ活 @rhnmb_1203 hourは1時間だけど、office hourっていう熟語？がある @rhnmb_1203 (1時間ってわけではない…) @rhnmb_1203 ガラス張りの施設だからGlass Boxやで GBC = galapagos box center
# は面白い @rhnmb_1203 そういうことになるな…笑 @rhnmb_1203 Glass Box office hour Center RT @gbc_hosei: こちら詳細です(っ'ヮ'c)！
# 立食形式で誰とも自由にお話ができます♪
# なにか質問があれば、当アカウントはDMを開放しておりますので(対応は4年生SA)気軽にご相談ください( *´︶`*)
# 5限に授業がある方も安心の途中退室可ですよ～！ https… RT @gbc_hosei: おはようございます！
# 本日はオープンラボ並びにGBC懇親会の日です
# ○オープンラボ　12:50～15:00
# ○GBC懇親会　15:10~16:50
# 懇親会には多くの先生方や院生の方々も参加されますので、オープンラボで聞き足りなかったことを聞くなど、… RT @rayrei1414: 過労キティ https://t.co/qi7BUIfW4m 手術日が決まった…… 社員さんの知識量やばすぎ 情科入門の来訪者多いな
# log_2(n)のチューリングマシンやっぱエグい RT @itsoku2ch: IT速報 : 任天堂、新作「大乱闘スマッシュブラザーズ」を12月7日発売決定！過去キャラ全員参戦、8人対戦対応や専用コントローラーも https://t.co/rRBUwvQ1z8 スマブラSpecial激アツやんけ！！！！！ 任天堂E3待機勢 研究室の飲み会の幹事に任命されて草 動画にコメントしたら投稿者本人から返事来た…！😭 そういうことか
#
# https://t.co/qq2aA9nVj7 何があったんや・・・ https://t.co/bnZkptZ1Jm と思ったら、平日も土曜も営業時間は11:30〜14:00やないかーい
# 営業終了前だから、そりゃ空いてるわ。 新しくできた食堂、空いてて良かった ぶっ飛びすぎてて笑う https://t.co/dx3OwwbPQx @Fusso3 あー、本物ってそういうことね・・・。それなら要らんわ笑 既存研究を改良するための研究だからやむを得ないのかな・・・
# 分からん システム図（仮）作ったはいいけど、既存研究少し変えた版になってしまったまずい @Fusso3 ほんまそれ
#
# 1セットあると便利かなって思った。複数枚は要らんけど笑 @Fusso3 PC上だと考えづらいから、めっちゃ捗る
#
# 是非欲しい笑 そしたらシステム図描き放題やな！ あんどぅーから貰ったホワイトボード使って卒研のシステム図考えてるけど、やりやすいぞ・・・！ 🤔🤔🤔 https://t.co/AdR0dceUMG RT @hoseicoop_kgn: 本日、入荷の新刊です。
#
# 夢見る機械学習
# 夢見るディープラーニング
# 会社で使われるスライドだから、骨折ネタ出すのはまだ早い 自己紹介スライドで自分の写真入れなきゃいけなくて、部活のLINEやら色々漁ったけど良い感じの見つからなかったから、研究室で電話に出た時に撮られたやつでも使うか()
# {
#     "word_count": 8201,
#     "processed_language": "ja",
#     "personality": [
#         {
#             "trait_id": "big5_openness",
#             "name": "Openness",
#             "category": "personality",
#             "percentile": 0.26615270771895105,
#             "raw_score": 0.5713597418775663,
#             "significant": true,
#             "children": [
#                 {
#                     "trait_id": "facet_adventurousness",
#                     "name": "Adventurousness",
#                     "category": "personality",
#                     "percentile": 0.7060027236315843,
#                     "raw_score": 0.5941583788255782,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_artistic_interests",
#                     "name": "Artistic interests",
#                     "category": "personality",
#                     "percentile": 0.18269227004493754,
#                     "raw_score": 0.6319304569037626,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_emotionality",
#                     "name": "Emotionality",
#                     "category": "personality",
#                     "percentile": 0.30689694847225135,
#                     "raw_score": 0.5963431408712266,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_imagination",
#                     "name": "Imagination",
#                     "category": "personality",
#                     "percentile": 0.10214766170756268,
#                     "raw_score": 0.7009581924992292,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_intellect",
#                     "name": "Intellect",
#                     "category": "personality",
#                     "percentile": 0.6107488542907374,
#                     "raw_score": 0.5495147484380842,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_liberalism",
#                     "name": "Authority-challenging",
#                     "category": "personality",
#                     "percentile": 0.11683769374961384,
#                     "raw_score": 0.45571609889751646,
#                     "significant": true
#                 }
#             ]
#         },
#         {
#             "trait_id": "big5_conscientiousness",
#             "name": "Conscientiousness",
#             "category": "personality",
#             "percentile": 0.8547521097041184,
#             "raw_score": 0.5200749181759207,
#             "significant": true,
#             "children": [
#                 {
#                     "trait_id": "facet_achievement_striving",
#                     "name": "Achievement striving",
#                     "category": "personality",
#                     "percentile": 0.7121151070971558,
#                     "raw_score": 0.5248665472752453,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_cautiousness",
#                     "name": "Cautiousness",
#                     "category": "personality",
#                     "percentile": 0.14750889125137118,
#                     "raw_score": 0.41982149668712887,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_dutifulness",
#                     "name": "Dutifulness",
#                     "category": "personality",
#                     "percentile": 0.920778233585859,
#                     "raw_score": 0.6875961466362244,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_orderliness",
#                     "name": "Orderliness",
#                     "category": "personality",
#                     "percentile": 0.9001991686823092,
#                     "raw_score": 0.3823496089780125,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_self_discipline",
#                     "name": "Self-discipline",
#                     "category": "personality",
#                     "percentile": 0.9624557252813881,
#                     "raw_score": 0.5128445677653288,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_self_efficacy",
#                     "name": "Self-efficacy",
#                     "category": "personality",
#                     "percentile": 0.9908575941766935,
#                     "raw_score": 0.6782736644819267,
#                     "significant": true
#                 }
#             ]
#         },
#         {
#             "trait_id": "big5_extraversion",
#             "name": "Extraversion",
#             "category": "personality",
#             "percentile": 0.9516858404193465,
#             "raw_score": 0.5737798059500345,
#             "significant": true,
#             "children": [
#                 {
#                     "trait_id": "facet_activity_level",
#                     "name": "Activity level",
#                     "category": "personality",
#                     "percentile": 0.8624657812898524,
#                     "raw_score": 0.4888512216982459,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_assertiveness",
#                     "name": "Assertiveness",
#                     "category": "personality",
#                     "percentile": 0.7513723294404543,
#                     "raw_score": 0.5516541891208595,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_cheerfulness",
#                     "name": "Cheerfulness",
#                     "category": "personality",
#                     "percentile": 0.7699280226774244,
#                     "raw_score": 0.6391508513604358,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_excitement_seeking",
#                     "name": "Excitement-seeking",
#                     "category": "personality",
#                     "percentile": 0.6291296280254958,
#                     "raw_score": 0.6280794950328187,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_friendliness",
#                     "name": "Outgoing",
#                     "category": "personality",
#                     "percentile": 0.9931205036911477,
#                     "raw_score": 0.5392805307267509,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_gregariousness",
#                     "name": "Gregariousness",
#                     "category": "personality",
#                     "percentile": 0.7271271524822557,
#                     "raw_score": 0.3887443436335354,
#                     "significant": true
#                 }
#             ]
#         },
#         {
#             "trait_id": "big5_agreeableness",
#             "name": "Agreeableness",
#             "category": "personality",
#             "percentile": 0.496667396918712,
#             "raw_score": 0.562365208858979,
#             "significant": true,
#             "children": [
#                 {
#                     "trait_id": "facet_altruism",
#                     "name": "Altruism",
#                     "category": "personality",
#                     "percentile": 0.02828424857758366,
#                     "raw_score": 0.5358089734939836,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_cooperation",
#                     "name": "Cooperation",
#                     "category": "personality",
#                     "percentile": 0.587524183820434,
#                     "raw_score": 0.56442586825368,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_modesty",
#                     "name": "Modesty",
#                     "category": "personality",
#                     "percentile": 0.1615752090280989,
#                     "raw_score": 0.4241923687204294,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_morality",
#                     "name": "Uncompromising",
#                     "category": "personality",
#                     "percentile": 0.6523587747360367,
#                     "raw_score": 0.5868307850952516,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_sympathy",
#                     "name": "Sympathy",
#                     "category": "personality",
#                     "percentile": 0.9834079570145542,
#                     "raw_score": 0.5075888006349123,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_trust",
#                     "name": "Trust",
#                     "category": "personality",
#                     "percentile": 0.6606594541262786,
#                     "raw_score": 0.622236565310098,
#                     "significant": true
#                 }
#             ]
#         },
#         {
#             "trait_id": "big5_neuroticism",
#             "name": "Emotional range",
#             "category": "personality",
#             "percentile": 0.21065862480803538,
#             "raw_score": 0.4009708042922503,
#             "significant": true,
#             "children": [
#                 {
#                     "trait_id": "facet_anger",
#                     "name": "Fiery",
#                     "category": "personality",
#                     "percentile": 0.09101169877721205,
#                     "raw_score": 0.4604963585293802,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_anxiety",
#                     "name": "Prone to worry",
#                     "category": "personality",
#                     "percentile": 0.01651687717922945,
#                     "raw_score": 0.5682665981534872,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_depression",
#                     "name": "Melancholy",
#                     "category": "personality",
#                     "percentile": 0.001107213660214823,
#                     "raw_score": 0.373123983025154,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_immoderation",
#                     "name": "Immoderation",
#                     "category": "personality",
#                     "percentile": 0.009285387809368661,
#                     "raw_score": 0.48734045557244593,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_self_consciousness",
#                     "name": "Self-consciousness",
#                     "category": "personality",
#                     "percentile": 0.06895698418943996,
#                     "raw_score": 0.4651966265874133,
#                     "significant": true
#                 },
#                 {
#                     "trait_id": "facet_vulnerability",
#                     "name": "Susceptible to stress",
#                     "category": "personality",
#                     "percentile": 0.004066924821234608,
#                     "raw_score": 0.398485198833577,
#                     "significant": true
#                 }
#             ]
#         }
#     ],
#     "needs": [
#         {
#             "trait_id": "need_challenge",
#             "name": "Challenge",
#             "category": "needs",
#             "percentile": 0.8288888745048226,
#             "raw_score": 0.6984683467436208,
#             "significant": true
#         },
#         {
#             "trait_id": "need_closeness",
#             "name": "Closeness",
#             "category": "needs",
#             "percentile": 0.47352854401175765,
#             "raw_score": 0.7528067045907261,
#             "significant": true
#         },
#         {
#             "trait_id": "need_curiosity",
#             "name": "Curiosity",
#             "category": "needs",
#             "percentile": 0.14852806803692298,
#             "raw_score": 0.6620160789409368,
#             "significant": true
#         },
#         {
#             "trait_id": "need_excitement",
#             "name": "Excitement",
#             "category": "needs",
#             "percentile": 0.7529352934832816,
#             "raw_score": 0.7285201760887091,
#             "significant": true
#         },
#         {
#             "trait_id": "need_harmony",
#             "name": "Harmony",
#             "category": "needs",
#             "percentile": 0.17903785414908746,
#             "raw_score": 0.7919047548221242,
#             "significant": true
#         },
#         {
#             "trait_id": "need_ideal",
#             "name": "Ideal",
#             "category": "needs",
#             "percentile": 0.09938260561793533,
#             "raw_score": 0.6569276955231419,
#             "significant": true
#         },
#         {
#             "trait_id": "need_liberty",
#             "name": "Liberty",
#             "category": "needs",
#             "percentile": 0.7847873125966568,
#             "raw_score": 0.6632945714171056,
#             "significant": true
#         },
#         {
#             "trait_id": "need_love",
#             "name": "Love",
#             "category": "needs",
#             "percentile": 0.40881533612350945,
#             "raw_score": 0.7048140695519195,
#             "significant": true
#         },
#         {
#             "trait_id": "need_practicality",
#             "name": "Practicality",
#             "category": "needs",
#             "percentile": 0.46731862441780436,
#             "raw_score": 0.7134345931083078,
#             "significant": true
#         },
#         {
#             "trait_id": "need_self_expression",
#             "name": "Self-expression",
#             "category": "needs",
#             "percentile": 0.13226270858563322,
#             "raw_score": 0.5963171930049999,
#             "significant": true
#         },
#         {
#             "trait_id": "need_stability",
#             "name": "Stability",
#             "category": "needs",
#             "percentile": 0.2513337498934709,
#             "raw_score": 0.7107768537006076,
#             "significant": true
#         },
#         {
#             "trait_id": "need_structure",
#             "name": "Structure",
#             "category": "needs",
#             "percentile": 0.1584636499243387,
#             "raw_score": 0.576479264826883,
#             "significant": true
#         }
#     ],
#     "values": [
#         {
#             "trait_id": "value_conservation",
#             "name": "Conservation",
#             "category": "values",
#             "percentile": 0.17514786662196663,
#             "raw_score": 0.6929498972857149,
#             "significant": true
#         },
#         {
#             "trait_id": "value_openness_to_change",
#             "name": "Openness to change",
#             "category": "values",
#             "percentile": 0.3102499537270069,
#             "raw_score": 0.7282291415431951,
#             "significant": true
#         },
#         {
#             "trait_id": "value_hedonism",
#             "name": "Hedonism",
#             "category": "values",
#             "percentile": 0.07933708651268312,
#             "raw_score": 0.784760688834608,
#             "significant": true
#         },
#         {
#             "trait_id": "value_self_enhancement",
#             "name": "Self-enhancement",
#             "category": "values",
#             "percentile": 0.488720706011731,
#             "raw_score": 0.7123095323154268,
#             "significant": true
#         },
#         {
#             "trait_id": "value_self_transcendence",
#             "name": "Self-transcendence",
#             "category": "values",
#             "percentile": 0.05240572799616994,
#             "raw_score": 0.7066577981621969,
#             "significant": true
#         }
#     ],
#     "warnings": []
# }
